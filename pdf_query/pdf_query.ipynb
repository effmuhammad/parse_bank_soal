# %%
from pdfquery import PDFQuery

pdf = PDFQuery('Simulasi-Tes-BUMN-5-8.pdf')
pdf.load()

# Use CSS-like selectors to locate the elements
text_elements = pdf.pq('LTTextLineHorizontal')

# Extract the text from the elements
text = [t.text for t in text_elements]

for t in text:
    print(t)
# Out:
# Kisi-kisi = ....
# A. Alat menangkap ikan
# B. Alat hitung
# C. Tabel
# D. Terali
# E. Pola kerja
# 2. Mudun = ....
# A. Problema
# B. Beradab
# C. Referensi
# D. Setuju
# E. Mufakat
#
#
#
#
#
#
# A. Pakaian kebesaran
# B. Makanan kenikmatan
# C. Dekorasi tataruang
# D. Pakaian pengantin
# E. Tata rias
# 4. Anjung = ....
# A. Dayung
# B. Panggung
# C. Buyung
# D. Puji
# E. Angkat
#
#
#
#
#
#
# A. Perpecahan
# B. Tidak berdaya
# C. Frustasi
# D. Sedih
# E. Putus harapan
#
# Rabun >< ....
# A. Tajam
# B. Terang
#
#
# C. Tepat
# D. Jelas
# E. Samar
# Surai >< ....
# A. Bubar
# B. Usai
# C. Purna
# D. Berhimpun
# E. Akhir
# Penerus >< ....
# A. Pewaris
# B. Kader
# C. Titisan
# D. Penemu
# E. Perintis
# 9. Hipokrit >< ....
# A. Jujur
# B. Pembohong
# C. Sabar
# D. Kamuflase
# E. Terbuka
#
#
#
#
#
# 10. Morfem >< ....
# A. Forum
# B. Lambang
# C. Morse
# D. Jantung
# E. Fonem
#
#
#
#
#
#
# A. Buruh : Demokrasi
# B. Makan : Kenyang
# C. MPR : UU
# D. Hakim : Jaksa
# E. Menteri : Kepres
#
# PAKET SOAL
# Tes Verbal
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 12. Otonomi : Mandiri = ….
# A. Hardisk : VGA card
# B. Sabun : Mandi
# C. Cerdas : Banyak akal
# D. Bensin : Mesin
# E. Rakyat : Masyarakat
#
#
#
#
#
#
# A. Perseteruan
# B. Pertengkaran
# C. Pertikaian
# D. Penyelarasan
# E. Persaingan
#
#
# A. Megawati
# B. Sudharmono
# C. Soekarno
# D. Soeharto
# E. Abdurrahman Wahid
#
# A. Srimpi
# B. Kecak
# C. Pendet
# D. Jaipong
# E. Angklung
#
# A. Einstein
# B. W. Shakespeare
# C. Graham Bell
# D. T. Alfa edison
# E. James Watt
# A. Pancur
# B. Selokan
# C. Ember
# D. Selang
# E. Keran
#
# A. 3.600 menit
# B. 60 deti
# C. 68.400 detik
# D. 1.440 menit
# E. 365 Hari
#
# A. Berjalan
# B. Tidur
# C. Kalori
# D. Teriakan
# E. Tersenyum
#
# A. Penyelidikan
# B. Pengusutan
# C. Penelitian
# D. Pemeriksaan
# E. Penuntutan
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Kisi-kisi dapat diartikan sebagai kayu atau besi
# yang dipasang berdiri dan berjarak sehingga
# terdapat celah-celah
# (pada tingkap dan
# sebagainya); terali; jeruji.
# 2. Pembahasan:
#  Mudun memiliki arti beradab.
#
#
#
# Boga adalah makanan; masakan; hidangan;
# santapan. Jadi, sinonim dari boga adalah
# makanan kenikmatan.
#
#
# Anjung bermakna bagian rumah (bilik) di sisi
# atau di tengah rumah yang lantainya lebih
# tinggi daripada lantai rumah. Jadi, sinonim
# dari anjung adalah panggung.
#
#
#
# 8. Pembahasan:
# Penerus
# (melanjutkan; menggantikan).
# Kata penerus berlawanan dengan kata perintis
# yang artinya yang memulai mengerjakan
# sesuatu, pelopor.
#
#
#
#
#
# Hipokrit bermakna munafik, orang yang suka
# berpura-pura.
# Kata hipokrit berantonim dengan kata jujur.
#
# 10. Pembahasan:
#  Morfem artinya satuan bentuk bahasa terkecil
# yang mempunyai makna secara relatif stabil
# dan tidak dapat dibagi atas bagian bermakna
# yang lebih kecil.
# Jadi, kata morfem berlawanan dengan kata
# fonem yang mempunyai arti satuan bunyi
# terkecil yang mampu menunjukkan kontras
# makna.
#
# Friksi berarti pergeseran yang menimbulkan
# perbedaan pendapat; perpecahan.
#
#
#
#
# Pemerintah bertugas untuk mengesahkan
# perpu. MPR bergutas mengesahan UU.
# Rabun bermakna kurang
# jelas; kurang
# awas; kabur
# (tentang penglihatan). Kata
# Rabun berantonim dengan kata jelas, yang
# mempunyai arti terang.
#
# Otonomi sama artinya dengan mandiri. Cerdas
# sama artinya dengan banyak akal.
#
#
#
#
# Surai bermakna bercerai-berai, usai, bubar.
# Jadi, kata surai berantonim dengan kata
# berhimpun yang mempunyai arti berkumpul.
# Jawaban: D
#
# Tempat untuk menampung rokok adalah
# asbak. Tempat untuk menampung air adalah
# ember.
#
#
# 1 minggu terdiri atas 7 hari. 1 hari terdiri dari
# 1.440 menit.
#
#
# PEMBAHASAN
# TES VERBAL
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Jika jatuh akan mengakibatkan terasa sakit.
# Jika mengantuk akan mengakibatkan tertidur
# (tidur).
#
#
# Semua kata yang disebutkan memiliki
# makna setara dengan investigasi, kecuali
# penuntutan.
#
#
# Semua kata bermakna permusuhan,
# kecuali penyelarasan yang bermakna
# positif.
#
#
# Semua adalah mantan presiden RI, kecuali
# Sudharmono.
#
#
# Semuanya adalah jenis-jenis tarian daerah
# kecuali angklung, alat musik.
#
#
# Semuanya merupakan
# ilmuwan atau
# penemu. Sedangkan W. Shakespeare
# adalah seorang penulis.
